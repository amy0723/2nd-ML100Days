# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# 作業1：
# 資料：CMS State Summary of Inpatient Charge Data
# 1.	監測美國各州不同DRG住院之醫療花費情形，供後續醫療保險政策/醫療補助計畫擬定之參考
# 2.	該數據是由美國CMS(類似台灣健保署)所建立的資料庫，為住院申報資料
# 3.	為結構化資料，共包含6個欄位，分別DRG Definition, Provider State, Total Discharges, Average Covered Charges, Average Total Payments, Average Medicare Payments
# 4.	以迴歸(MSE)預測不同州別、不同DRG的住院花費
#
# 作業2：
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 1.	如何開發新客源以及留住原有顧客為提升業績之關鍵，因此假設：
# H1:提升顧客叫車時的可近性，會使業績上升(開發新客源)
# H2:提高顧客滿意度會使業績上升(留住原有顧客)
# 2.	透過叫車App蒐集上述2項資料，主要蒐集叫車/乘車紀錄以及服務完成後的顧客滿意度
# 3.	資料型態屬於結構化資料，主要包含2部分：叫車/乘車紀錄(叫車地點、叫車時間、抵達地點、車程時間)，若取消叫車則須包含取消原因，為封閉式問答；另一部份則顧客滿意度，針對候車時間、司機態度、以及車內環境各一題，以李克特五分法供顧客勾選。
# 4.	透過資料蒐集後，針對可近差地區(尖峰時間但車少，導致取消率高)進行人力調派，之後測量改善地區之取消率是否有降低，以及該地區服務量是否提升。另外對於原有顧客，則依據滿意度結果進行各面向改善，爾後以趨勢分析測量該面向的分數是否有提升；另外再針對每一顧客進行重複測量，看顧客滿意度分數是否有進步。由於註冊App時需填寫基本資料，因此可以預測不同時段客群的樣貌。

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_square_error(y, yp):
    """    
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """

    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean squsre error is %.3f" % (MSE))
# Out:
# The Mean squsre error is 236.253

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.298

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 200.029
# The Mean absolute error is 11.266
